# %%
import sys
sys.path.append("../TI_modules/")
import TI_greensfn
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
TIG0=TI_greensfn.init_material(npix=40)

# %%
TIG0.setup_potential(vamp=1.5e-18)
figure()
imshow(abs(TIG0.V),origin="lower")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
TIG0.omega=0.2
G0=TIG0.return_G0(do_vis=True,x_tip=13,y_tip=23)
figure()
imshow(abs(G0))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
TIG0.gen_G0_all(E=0.1)
figure()
imshow(log10(abs(TIG0.G0all)),origin="lower")
colorbar()
# TIG0.get_Gnew()
# ldos=TIG0.get_ldos()
# figure()
# imshow(ldos,origin="lower")
# colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/garima/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
E=linspace(-0.29,0.29,20)
ldos=np.zeros_like(E)
for i,omega in enumerate(E):
    TIG0.gen_G0_all(E=omega)
    TIG0.get_Gnew()
    ldos[i]=TIG0.get_ldos(loc=[20,20])
    print i,omega,ldos[i]
# Out:
# 0 -0.29 5.86455862202e+17
# 1 -0.259473684211 5.74612562815e+17
# 2 -0.228947368421 1.73425663923e+17
# 3 -0.198421052632 3.8379969167e+17
# 4 -0.167894736842 3.0959603572e+17
# 5 -0.137368421053 1.04417562032e+17
# 6 -0.106842105263 1.80262572044e+17
# 7 -0.0763157894737 1.67703351547e+17
# 8 -0.0457894736842 3.34006963961e+16
# 9 -0.0152631578947 2.91085874528e+16
# 10 0.0152631578947 1.23077018779e+16
# 11 0.0457894736842 1.23285816302e+17
# 12 0.0763157894737 1.07539264068e+17
# 13 0.106842105263 7.53134175134e+16
# 14 0.137368421053 3.10440590305e+17
# 15 0.167894736842 2.95748389019e+17
# 16 0.198421052632 1.70825946816e+17
# 17 0.228947368421 2.98360382921e+17
# 18 0.259473684211 7.68020875355e+17
# 19 0.29 4.0816454163e+17

# %%
figure()
plot(E,(ldos)/1e18)
# Out:
# <img src="data:image/png;base64,..." width="640">
