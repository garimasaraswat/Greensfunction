# %%
import sys,os
sys.path.append("../TI_modules/")
import TI_greensfn_parallel as TI_greensfn
# %pylab notebook
import time
import multiprocessing as mp
def ensure_dir(file_path):
    directory = os.path.dirname(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)
        
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sb=TI_greensfn.init_material(npix=16,pixwid=0.25e-9,band_cutoff=0.6)

# %%
a=imread("../../../Data/4K/November2017/17k15/17k15_PbACdepo011.png")
img=a[:,:,1]
figure()
imshow(img, origin='lower')
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fn="pt4V"
figpath="../results/figures/"+fn
ensure_dir(figpath)


jpegpath=figpath + "/png/"
ensure_dir(jpegpath)

# %%
sb.setup_potential(rad=.3e-9,po_type="hexisland",V0=4.0,edgewid=0.05,smwid=0.0)

figure()
imshow(real(sb.V)/(sb.pixwid**2.),origin="lower",extent=[0.0 , sb.npix*sb.pixwid, 0.0 , sb.npix*sb.pixwid])
colorbar()
#savefig(figpath+"hexminus1p5V.pdf",bbox_inches="tight")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
start=time.time()
omega=np.linspace(-0.29,0.29,50)
ldos=np.zeros((omega.shape[0],sb.npix,sb.npix))
for i, E in enumerate(omega):
    ldos[i,:,:]=sb.get_ldos_Gnew(E=E,method="T",loc=[])
endt= time.time()-start
endt
# Out:
# 15.51873517036438

# %%
t=np.loadtxt("../results/figures/pt2V"+"/"+'pt2Vcentcutoffp6.txt')

# %%
figure()
title("LDOS at center of V=0.5eV $nm^2$ square")
plot(omega,ldos[:,8,8],label="side=0.5 nm")
plot(t[0,:],t[1,:],label="side=1 nm")
#text(-0.1, 0.8, r'$\Delta E=\frac{\hbar v_f \pi}{R} =95 meV$', fontsize=15)
ylabel("LDOS (arb. u.)",fontsize=12)
xlabel("Energy (eV)",fontsize=12)
rc('axes', linewidth=1)
legend(loc="upper right")
#grid()
#xticks(numpy.arange(-0.25, 0.25, 0.05))
tick_params(direction="in")
tick_params(labelsize=14)
savefig(figpath+"/"+"1nmsqr.pdf",bbox_inches="tight")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.savetxt(figpath+"/"+fn+'centcutoffp6.txt', (omega,ldos[:,8,8]))

# %%
ioff()
for i,E in enumerate(omega):
    fig,(ax1,ax2)=subplots(ncols=2,figsize=(9,3))
    img1 = ax1.imshow(real(sb.V)/(sb.pixwid**2.),origin="lower",extent=[0.0 , sb.npix*sb.pixwid, 0.0 , sb.npix*sb.pixwid])
    ax1.set_title(r"Scattering potential ($eV$)")
    divider = make_axes_locatable(ax1)
    cax1 = divider.append_axes("right", size="5%", pad=0.08)
    fig.colorbar(img1, cax=cax1)

    img2 = ax2.imshow(ldos[i,],origin="lower",extent=[0.0 , sb.npix*sb.pixwid, 0.0 , sb.npix*sb.pixwid])
    ax2.set_title(r"$\epsilon=$" + str(round(E,2)) + " eV")
    divider = make_axes_locatable(ax2)
    cax2 = divider.append_axes("right", size="5%", pad=0.08)
    cbar=fig.colorbar(img2, cax=cax2)
    cbar.formatter.set_powerlimits((0,0))
    cbar.update_ticks()
    filename=jpegpath + "ldos_" + str(i).zfill(2) + ".png"
    savefig(filename,bbox_inches="tight")

workdir=os.getcwd()
os.chdir(figpath)
cmd="convert -quality 99 -density 150 -delay 100 -loop 0 ./jpeg/ldos_*.png ldos_evolve.gif"
print (cmd)
os.system(cmd)
os.chdir(workdir)
ion()
# Out:
# c:\users\saraswat\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# convert -quality 99 -density 150 -delay 100 -loop 0 ./jpeg/ldos_*.png ldos_evolve.gif

# %%
def linescan(slope=1,intrcpt=0,npix=sb.npix): 
#'''given the slope and intercept of linescan, this function returns the pixel coordinates'''
    a= []
    b=[]
    for x in linspace(0,npix,4*npix):
        i=int(x)
        j=np.int(np.floor(slope*x+intrcpt))
        if j in range(npix):
            a.append(i)
            b.append(j) 
        loc=set(zip(a,b))
        loc=list(loc)
    return loc
        
# V=np.zeros((sb.npix,sb.npix))
# for x in range(size(i)):
#     V[i[x],j[x]]=1.
# figure()
# imshow(V*3e-18+real(sb.V),origin="lower")
        
figure()
jet=get_cmap('jet')
loc=linescan()
colors=iter(jet(np.linspace(0,1,len(loc))))
for x in range(len(loc)-1):
    plot(omega,ldos[:,loc[x][0],loc[x][1]], color=next(colors))
ylabel("LDOS (arb. u.)",fontsize=12)
xlabel("Energy (eV)",fontsize=12)
rc('axes', linewidth=1)
tick_params(direction="in")
tick_params(labelsize=14)
#savefig("img0p5eV.pdf",bbox_inches="tight")
# Out:
# c:\users\saraswat\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <img src="data:image/png;base64,..." width="640">

# %%
from mpl_toolkits import mplot3d
X=np.arange(1,len(loc)+1,dtype='int')
Y=omega
Z=ldos[:,loc[0][0],loc[0][1]]
for i in range(len(loc)-1):
    Z=np.vstack((Z,ldos[:,loc[i+1][0],loc[i+1][1]]))
Z=np.transpose(Z)
X, Y = np.meshgrid(X, Y)
fig = figure()
ax = fig.gca(projection='3d')
#ax.set_title('18h07S0005')
surf = ax.plot_surface(X, Y, Z, cmap=cm.jet,rstride=1, cstride=1, linewidth=0, antialiased=False)
#ax.set_xlim(1,64)
ax.view_init(azim=0, elev=90)
fig.colorbar(surf, shrink=0.5, aspect=5,label=r"ldos(arb. unit)")
ax.set_ylabel("Voltage (V)")
ax.set_zticklabels([])
ax.set_xlabel("# point")
#savefig("64px10nm54sitesdiagline.pdf",bbox_inches="tight")
# Out:
# c:\users\saraswat\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if __name__ == '__main__':
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, '# point')
