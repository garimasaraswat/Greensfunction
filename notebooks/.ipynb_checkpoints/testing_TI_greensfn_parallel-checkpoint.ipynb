# %%
import sys,os
sys.path.append("../TI_modules/")
import TI_greensfn_parallel as TI_greensfn
# %pylab notebook
import time
import multiprocessing as mp
def ensure_dir(file_path):
    directory = os.path.dirname(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)
        
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sb=TI_greensfn.init_material(npix=32,pixwid=1e-9)

# %%
img=np.loadtxt("../../../Data/STM_raw_data/4K/Aug2018/18h08/18h08T0008.txt")

# %%
sb.setup_potential(rad=12e-9,po_type="circ",edgewid=0.01,smwid=0.0,img=img)

figure()
imshow(real(sb.V))
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
GnewT=sb.get_Gnew_fromT(E=0.01)

# %%
Gnew=sb.get_Gnew(E=0.01)

# %%
figure()
imshow(abs(GnewT))
colorbar()
figure()
imshow(abs(Gnew))
colorbar()
figure()
imshow(log(abs(imag(GnewT-Gnew)/imag(Gnew))))
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# /Users/garima/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log

# %%
start=time.time()
LdosG0T=sb.get_ldos_Gnew(method="T",E=0.18)
print time.time()-start
start=time.time()
LdosG=sb.get_ldos_Gnew(method="S",E=0.18)
print time.time()-start
# Out:
# 4.8521490097
# 6.3352599144

# %%
figure()
imshow((LdosG0T))
colorbar()
figure()
imshow((LdosG))
colorbar()
figure()
imshow(abs(LdosG0T-LdosG))
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
def run_fn(E):
    ldos=sb.get_ldos_Gnew(E=E,loc=[])
    return ldos

def run_ldos_in_parallel(numprocs,Emin,Emax,nstep):
    E=np.linspace(Emin,Emax,nstep)
    pool=mp.Pool(processes=numprocs)
    ldos=pool.map(run_fn,E)
    pool.close()
    pool.join()
    return E,ldos

# %%
start=time.time()
E,ldos=run_ldos_in_parallel(1,-0.15,0.15,10)
ldos=np.array(ldos)
print time.time()-start
# Out:
# 46.1565179825

# %%
figure()
for i in range(sb.npix):
    j=3*i+2
    if j in range(sb.npix):
        plot(E,ldos[:,i,j])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
V=np.zeros((sb.npix,sb.npix))
a= []
b=[]
for x in linspace(0,sb.npix,4*sb.npix):
    i=int(x)
    j=np.int(np.floor(-(np.sqrt(3))*x+16))
    if j in range(sb.npix):
        a.append(i)
        b.append(j)
    i = np.array(a)  
    j = np.array(b) 

for x in range(size(i)):
    V[i[x],j[x]]=1.
        
figure()
imshow(V,origin="lower")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fn="atoms"
figpath="../results/figures/"+fn
ensure_dir(figpath)


jpegpath=figpath + "/jpeg/"
ensure_dir(jpegpath)

ioff()
for i,omega in enumerate(E):
    fig,(ax1,ax2)=subplots(ncols=2,figsize=(9,3))
    img1 = ax1.imshow(real(sb.V)/1e-18,origin="lower")
    ax1.set_title(r"V ($\times 10^{-18}$)")
    divider = make_axes_locatable(ax1)
    cax1 = divider.append_axes("right", size="5%", pad=0.08)
    fig.colorbar(img1, cax=cax1)

    img2 = ax2.imshow(ldos[i,]/1e18,origin="lower")
    ax2.set_title(r"$\epsilon=$" + str(round(omega,2)) + " eV")
    divider = make_axes_locatable(ax2)
    cax2 = divider.append_axes("right", size="5%", pad=0.08)
    cbar=fig.colorbar(img2, cax=cax2)
    cbar.formatter.set_powerlimits((0,0))
    cbar.update_ticks()
    filename=jpegpath + "ldos_" + str(i).zfill(2) + ".jpeg"
    savefig(filename,bbox_inches="tight")

workdir=os.getcwd()
os.chdir(figpath)
cmd="convert -quality 99 -density 150 -delay 100 -loop 0 ./jpeg/ldos_*.jpeg ldos_evolve.gif"
print cmd
os.system(cmd)
os.chdir(workdir)
ion()
# Out:
# convert -quality 99 -density 150 -delay 100 -loop 0 ./jpeg/ldos_*.jpeg ldos_evolve.gif

# %%
np.zeros?

# %%
V.shape
# Out:
# (32,)
