# %%
import sys
sys.path.append("../modules/")
import object_dos1D
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dos1=object_dos.dos_calculator(xnpix=60,E=0.5)

# %%
dos1.return_lambda()
dos1.dbglambda
dos1.return_G0all()

# %%
def return_gaussianV(xnpix=dos1.xnpix,ynpix=dos1.ynpix,pixwid=dos1.pixwid,x_imp=15,y_imp=15,sigma=2.,amp=0.02):
    gaussianV=np.zeros((xnpix,ynpix),dtype=np.float32)
    x,y=np.indices(gaussianV.shape)
    gaussianV=amp*(1./(2.*np.pi*sigma**2.))*np.exp(-((x-x_imp)**2.+(y-y_imp)**2.)/(2.*sigma**2.))
    return gaussianV

# %%
V=return_gaussianV()
figure()
imshow(V,origin='lower')
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dos1.get_Gnew(V=V)

# %%
figure()
imshow(log10(abs(dos1.dos)),origin='lower')
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/garima/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10

# %%
figure()
imshow(log10((abs(dos1.Gnew[:,70].reshape(dos1.xnpix,dos1.ynpix)))),origin='lower')
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x=linspace(0,20,100)

# %%
y=x.ravel()

# %%
z=y.reshape(100,1)

# %%
z
# Out:
# array([[  0.        ],
#        [  0.2020202 ],
#        [  0.4040404 ],
#        [  0.60606061],
#        [  0.80808081],
#        [  1.01010101],
#        [  1.21212121],
#        [  1.41414141],
#        [  1.61616162],
#        [  1.81818182],
#        [  2.02020202],
#        [  2.22222222],
#        [  2.42424242],
#        [  2.62626263],
#        [  2.82828283],
#        [  3.03030303],
#        [  3.23232323],
#        [  3.43434343],
#        [  3.63636364],
#        [  3.83838384],
#        [  4.04040404],
#        [  4.24242424],
#        [  4.44444444],
#        [  4.64646465],
#        [  4.84848485],
#        [  5.05050505],
#        [  5.25252525],
#        [  5.45454545],
#        [  5.65656566],
#        [  5.85858586],
#        [  6.06060606],
#        [  6.26262626],
#        [  6.46464646],
#        [  6.66666667],
#        [  6.86868687],
#        [  7.07070707],
#        [  7.27272727],
#        [  7.47474747],
#        [  7.67676768],
#        [  7.87878788],
# ...
