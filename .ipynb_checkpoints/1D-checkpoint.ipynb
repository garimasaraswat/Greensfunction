# %%
from GF_analysis import object_dos1D
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dos1=object_dos1D.dos_calculator(xnpix=200,E=0.1)

# %%
dos1.return_lambda()
dos1.dbglambda
dos1.return_G0all1D()

# %%
figure()
imshow(abs(dos1.G0all))
#colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dos1.return_G01D(x_tip=100)
figure()
plot(real(dos1.G0.flatten()))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def return_gaussianV(xnpix=dos1.xnpix,ynpix=dos1.ynpix,pixwid=dos1.pixwid,x_imp=150,y_imp=1,sigma=1.,amp=0.002):
    gaussianV=np.zeros((xnpix,ynpix),dtype=np.float32)
    x,y=np.indices(gaussianV.shape)
    gaussianV=amp*(1./(2.*np.pi*sigma**2.))*np.exp(-((x-x_imp)**2.+(y-y_imp)**2.)/(2.*sigma**2.))
    return gaussianV

# %%
V=return_gaussianV()
figure()
plot(V)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Vall=np.diag(V.ravel())
figure()
imshow(Vall)
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dos1.get_Gnew(V=V)

# %%
figure()
plot((abs(dos1.dos.flatten())))
plot(V*1e21)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
figure()
plot((abs(dos1.Gnew[:,175].reshape(dos1.xnpix,dos1.ynpix))))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
k=0.1
r=np.arange(200)-100
g=np.exp(1j*k*r)/k

# %%
figure()
plot(r,imag(g))
plot(r,real(g))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
I0=identity(dos1.xnpix,dtype=np.complex)

# %%
G0V=np.matmul(dos1.G0all,Vall)

# %%
Gnew=np.linalg.solve(I0-G0V,dos1.G0all)

# %%
dos=np.imag(np.diag(Gnew)).reshape(dos1.xnpix,dos1.ynpix)

# %%
figure()
plot(abs(dos))
plot(dos1.dos.flatten())
# Out:
# <img src="data:image/png;base64,..." width="640">
